# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_lowpass_filter(order: int) -> np.array:
    """
    """
    return np.ones(shape=(order, order)) * (1/order**2)


def get_laplacian_filter(type: str) -> np.array:
    """
    """
    return mask


def convolution(image: np.array, mask: np.array) -> np.array:
    """
    """
    #
    mask = np.flipud(np.fliplr(mask))

    #
    order = mask.shape[0]
    half_order = order//2

    #
    result = np.zeros(shape=(image.shape))
    image = np.pad(image, half_order)
    M, N = image.shape

    for i in range(0, M - order):
        for j in range(0, N - order):
            result[i, j] = (mask * image[i:i+order, j:j+order]).sum()

    return result

# %%
get_laplacian_filter(3)
# Out:
# array([[-0.08285868, -0.04782394, -0.04782394],
#        [-0.04782394, -0.02436544, -0.02436544],
#        [-0.04782394, -0.02436544, -0.02436544]])

# %%
image = plt.imread('../images/lena.tif').astype('uint8')

# %%
lowpass_mask = get_lowpass_filter(11)
lowpass_filter_image = convolution(image, lowpass_mask)
plt.imshow(lowpass_filter_image, cmap='gray')

# %%
# lowpass_mask = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
lowpass_mask = get_laplacian_filter(3)
lowpass_filter_image = convolution(image, lowpass_mask)
plt.imshow(lowpass_filter_image, cmap='gray')

# %%
plt.imshow(image, cmap='gray', vmin=0, vmax=255)

# %%
lowpass_mask = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
lowpass_filter_image = convolution(image, lowpass_mask)
plt.imshow(lowpass_filter_image, cmap='gray', vmin=0, vmax=255)

# %%
moon = plt.imread('../images/Fig3.40(a).jpg').astype('uint8')
lowpass_mask = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# lowpass_mask = np.array([[0, 1, 0], [1, -4, 1], [0, 1, 0]])

lowpass_filter_image = convolution(moon, lowpass_mask)
plt.imshow(lowpass_filter_image, cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(moon, cmap='gray', vmin=0, vmax=255)
